# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score 
from sklearn import metrics 
from sklearn.metrics import precision_recall_fscore_support 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data= pd.read_csv('/content/drive/MyDrive/Marketing-Analytics/Data/conversion_rates.csv')
data.head(5)
# Out:
#    converted group
# 0          0     B
# 1          0     B
# 2          0     A
# 3          0     B
# 4          0     A

# %%
data['converted'].value_counts()
# Out:
# 0    1889
# 1     111
# Name: converted, dtype: int64

# %%
data['group'].value_counts()
# Out:
# A    1030
# B     970
# Name: group, dtype: int64

# %%
data[data['converted'] ==0]['group'].value_counts()
# Out:
# B    949
# A    940
# Name: group, dtype: int64

# %%
data[data['converted'] ==1]['group'].value_counts(0)
# Out:
# A    90
# B    21
# Name: group, dtype: int64

# %% [markdown]
# Group A has a higher conversion rate.

# %%
round(data[data['converted'] ==1]['group'].value_counts(1),2)
# Out:
# A    0.81
# B    0.19
# Name: group, dtype: float64
